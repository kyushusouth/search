# %%
from pathlib import Path

import pandas as pd

# %%
root_dir = Path("~/dev/search").expanduser()
df_products = pd.read_parquet(
    root_dir.joinpath("data", "shopping_queries_dataset_products.parquet")
)
df_products
# Out:
#          product_id                                      product_title  \
# 0        B079VKKJN7  11 Degrees de los Hombres Playera con Logo, Ne...
# 1        B079Y9VRKS          Camiseta Eleven Degrees Core TS White (M)
# 2        B07DP4LM9H  11 Degrees de los Hombres Core Pull Over Hoodi...
# 3        B07G37B9HP          11 Degrees Poli Panel Track Pant XL Black
# 4        B07LCTGDHY  11 Degrees Gorra Trucker Negro OSFA (Talla úni...
# ...             ...                                                ...
# 1814919  B09FJYBVKS  スポーツブラ 揺れない ヨガウェア レディース トップス 通気性 ナイトブラ スポーツブラジ...
# 1814920  B09FTJ3S1N  ブラジャー レディース 補正ブラ Gabrioir 揺れない 大きいサイズ バストアップ美胸...
# 1814921  B09G72LDQZ  レディース ブラジャー 補正ブラ トップス Gabrioir 大きいサイズ 揺れない 脇高設...
# 1814922  B09GBGRTPB  ナイトブラ ノンワイヤーブラ ブラジャー レディース Gabrioir 大きいサイズ パット...
# 1814923  B09GBKN83Q  インナーキャミソール レディース ブラトップ キャミソール Gabrioir ノーワイヤー ...
#
#                                        product_description  \
# ...

# %%
root_dir = Path("~/dev/search").expanduser()

df_examples = pd.read_parquet(
    root_dir.joinpath("data", "shopping_queries_dataset_examples.parquet")
)
df_products = pd.read_parquet(
    root_dir.joinpath("data", "shopping_queries_dataset_products.parquet")
)
df_sources = pd.read_csv(
    root_dir.joinpath("data", "shopping_queries_dataset_sources.csv")
)

df_examples_products = pd.merge(
    df_examples,
    df_products,
    how="left",
    on=["product_locale", "product_id"],
)
df_task_1 = df_examples_products[df_examples_products["small_version"] == 1]
df_task_1_train = df_task_1[df_task_1["split"] == "train"].copy()
df_task_1_test = df_task_1[df_task_1["split"] == "test"].copy()

# %%
df_task_1["product_id"].nunique(), df_task_1.shape
# Out:
# (879141, (1118011, 14))

# %%
df_task_1[["product_id", "product_locale", "product_title", "product_description", "product_bullet_point", "product_brand", "product_color"]].drop_duplicates()
# Out:
#          product_id product_locale  \
# 16       B075SCHMPY             us
# 17       B08L3B9B9P             us
# 18       B082K7V2GZ             us
# 19       B07P4CF3DP             us
# 20       B07C1WZG12             us
# ...             ...            ...
# 2621251  B0719GBJW2             jp
# 2621252  B000O1PKEG             jp
# 2621253  B000AQXZH4             jp
# 2621254  B000AQXWDG             jp
# 2621255  4635450384             jp
#
#                                              product_title  \
# 16       RamPro 10" All Purpose Utility Air Tires/Wheel...
# 17       MaxAuto 2-Pack 13x5.00-6 2PLY Turf Mower Tract...
# 18       NEIKO 20601A 14.5 inch Steel Tire Spoon Lever ...
# 19       2PK 13x5.00-6 13x5.00x6 13x5x6 13x5-6 2PLY Tur...
# 20       (Set of 2) 15x6.00-6 Husqvarna/Poulan Tire Whe...
# ...                                                    ...
# 2621251  MiliCamp キャンプ用 メスティン アウトドア炊飯 飯盒 バリ取り不要 登山 山飯 M...
# ...
